# %%
import pandas as pd
data = { 'apples' : [3, 2, 0, 1], 'oranges': [ 0,3,7,2] }
df =pd.DataFrame(data)
df
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
import pandas as pd
data = { 'stu_id' : [1, 2, 3, 4, 5 ] , 'name' : [ 'deekshitha', 'sharvani', 'sathvika', 'yamuna','mahaa'], 'dept' : ['cse', 'ece','eee', 'aiml','aids']  }
df =pd.DataFrame(data, index = ['A', 'B', 'C', 'D', 'E'])
df
# Out:
#    stu_id        name  dept
# A       1  deekshitha   cse
# B       2    sharvani   ece
# C       3    sathvika   eee
# D       4      yamuna  aiml
# E       5       mahaa  aids

# %%
import pandas as pd
data = { 'stu_id' : [1, 2, 3, 4, 5 ] , 'name' : [ 'deekshitha', 'sharvani', 'sathvika', 'yamuna','mahaa'], 'dept' : ['cse', 'ece','eee', 'aiml','aids']  }
df =pd.DataFrame(data, index = ['00', '01', '02', '03', '04'])
df
df.loc['00']
# Out:
# stu_id             1
# name      deekshitha
# dept             cse
# Name: 00, dtype: object

# %%
from google.colab import files
files.upload()

import pandas as pd

df = pd.read_csv("Iris.csv")

df
# Out:
#      <input type="file" id="files-323c9854-0973-4766-bd65-8bd225fabfd7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-323c9854-0973-4766-bd65-8bd225fabfd7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = { 'stu_id' : [1, 2, 3, 4, 5 ] , 'name' : [ 'deekshitha', 'sharvani', 'sathvika', 'yamuna','mahaa'], 'dept' : ['cse', 'ece','eee', 'aiml','aids']  }
df =pd.DataFrame(data, index = ['A', 'B', 'C', 'D', 'E'])
df.to_csv('new_dataset.csv')
df
# Out:
#    stu_id        name  dept
# A       1  deekshitha   cse
# B       2    sharvani   ece
# C       3    sathvika   eee
# D       4      yamuna  aiml
# E       5       mahaa  aids

# %%
import pandas as pd
data = { 'stu_id' : [1, 2, 3, 4, 5 ] , 'name' : [ 'deekshitha', 'sharvani', 'sathvika', 'yamuna','mahaa'], 'dept' : ['cse', 'ece','eee', 'aiml','aids']  }
df =pd.DataFrame(data, index = ['A', 'B', 'C', 'D', 'E'])
df.to_json('new_dataset.json')
df
# Out:
#    stu_id        name  dept
# A       1  deekshitha   cse
# B       2    sharvani   ece
# C       3    sathvika   eee
# D       4      yamuna  aiml
# E       5       mahaa  aids

# %%
movies_df = pd.read_csv("movies.csv.zip", index_col="title")
movies_df
# Out:
#                                           index     budget  \
# title
# Avatar                                        0  237000000
# Pirates of the Caribbean: At World's End      1  300000000
# Spectre                                       2  245000000
# The Dark Knight Rises                         3  250000000
# John Carter                                   4  260000000
# ...                                         ...        ...
# El Mariachi                                4798     220000
# Newlyweds                                  4799       9000
# Signed, Sealed, Delivered                  4800          0
# Shanghai Calling                           4801          0
# My Date with Drew                          4802          0
#
#                                                                             genres  \
# title
# Avatar                                    Action Adventure Fantasy Science Fiction
# ...

# %%
movies_df.head(4)
# Out:
#                                           index     budget  \
# title
# Avatar                                        0  237000000
# Pirates of the Caribbean: At World's End      1  300000000
# Spectre                                       2  245000000
# The Dark Knight Rises                         3  250000000
#
#                                                                             genres  \
# title
# Avatar                                    Action Adventure Fantasy Science Fiction
# Pirates of the Caribbean: At World's End                  Adventure Fantasy Action
# Spectre                                                     Action Adventure Crime
# The Dark Knight Rises                                  Action Crime Drama Thriller
#
#                                                                               homepage  \
# title
# Avatar                                                     http://www.avatarmovie.com/
# ...

# %%
movies_df.tail(4)
# Out:
#                            index  budget                         genres  \
# title
# Newlyweds                   4799    9000                 Comedy Romance
# Signed, Sealed, Delivered   4800       0  Comedy Drama Romance TV Movie
# Shanghai Calling            4801       0                            NaN
# My Date with Drew           4802       0                    Documentary
#
#                                                                     homepage  \
# title
# Newlyweds                                                                NaN
# Signed, Sealed, Delivered  http://www.hallmarkchannel.com/signedsealeddel...
# Shanghai Calling                                 http://shanghaicalling.com/
# My Date with Drew                                                        NaN
#
#                                id  \
# title
# Newlyweds                   72766
# Signed, Sealed, Delivered  231617
# Shanghai Calling           126186
# My Date with Drew           25975
#
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4803 entries, Avatar to My Date with Drew
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 4803 non-null   int64
#  1   budget                4803 non-null   int64
#  2   genres                4775 non-null   object
#  3   homepage              1712 non-null   object
#  4   id                    4803 non-null   int64
#  5   keywords              4391 non-null   object
#  6   original_language     4803 non-null   object
#  7   original_title        4803 non-null   object
#  8   overview              4800 non-null   object
#  9   popularity            4803 non-null   float64
#  10  production_companies  4803 non-null   object
#  11  production_countries  4803 non-null   object
#  12  release_date          4802 non-null   object
#  13  revenue               4803 non-null   int64
# ...

# %%
movies_df.shape
# Out:
# (4803, 23)

# %%
movies_df = movies_df.drop_duplicates()

# %%
movies_df.drop_duplicates(inplace=True)

# %%
k=pd.concat([movies_df, movies_df])
k
k.shape
movies_df.describe()
# Out:
#              index        budget             id   popularity       revenue  \
# count  4803.000000  4.803000e+03    4803.000000  4803.000000  4.803000e+03
# mean   2401.000000  2.904504e+07   57165.484281    21.492301  8.226064e+07
# std    1386.651002  4.072239e+07   88694.614033    31.816650  1.628571e+08
# min       0.000000  0.000000e+00       5.000000     0.000000  0.000000e+00
# 25%    1200.500000  7.900000e+05    9014.500000     4.668070  0.000000e+00
# 50%    2401.000000  1.500000e+07   14629.000000    12.921594  1.917000e+07
# 75%    3601.500000  4.000000e+07   58610.500000    28.313505  9.291719e+07
# max    4802.000000  3.800000e+08  459488.000000   875.581305  2.787965e+09
#
#            runtime  vote_average    vote_count
# count  4801.000000   4803.000000   4803.000000
# mean    106.875859      6.092172    690.217989
# std      22.611935      1.194612   1234.585891
# min       0.000000      0.000000      0.000000
# 25%      94.000000      5.600000     54.000000
# ...

# %%
import pandas as pd
mis = [{'a' : 1, 'b' : 2}, {'a' : 5, 'b' : 10, 'c' : 20}]
df1 = pd.DataFrame(mis, index['first', 'second'], coloumns=['a','b'])
df2 = pd.DataFrame(mis,index['first', 'second'], coloumns=['a','b1'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_614/2911639837.py in <cell line: 0>()
#       1 import pandas as pd
#       2 mis = [{'a' : 1, 'b' : 2}, {'a' : 5, 'b' : 10, 'c' : 20}]
# ----> 3 df1 = pd.DataFrame(mis, index['first', 'second'], coloumns=['a','b'])
#       4 df2 = pd.DataFrame(mis,index['first', 'second'], coloumns=['a','b1'])
#       5 df
#
# NameError: name 'index' is not defined

# %%
d = { 'one' : pd.Series([1,2,3], index['a','b','c']),
     'two' : pd.Series([1,2,3,4], index['a','b','c','d'])
     }
df = pd.DataFrame(d)
print("Adding a new coloumn by passing as Series:")
df['three'] = pd.Series([10,20,30])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_614/1722308310.py in <cell line: 0>()
# ----> 1 d = { 'one' : pd.Series([1,2,3], index['a','b','c']),
#       2      'two' : pd.Series([1,2,3,4], index['a','b','c','d'])
#       3      }
#       4 df = pd.DataFrame(d)
#       5 print("Adding a new coloumn by passing as Series:")
#
# NameError: name 'index' is not defined

# %%
import pandas as pd

df1 = pd.DataFrame(['A' :]
    {
        "B": [123, 456, 789, 111],
        "C": [234, 567, 890, 222],
        "D": [1234, 5678, 9101, 3333]
    },
    index=["a1", "a2", "a3", "a4"]
)

df1

# %%
import pandaas as pd
df=pd.read.csv('movies.csv')
total_nans = df.isna().sum().sum()

nans_per_coloumn = df.isna().sum()

print("Total NaNs:" total_nans)

# %%
movies_df.dropna()
# Out:
#                                           index     budget  \
# title
# Avatar                                        0  237000000
# Pirates of the Caribbean: At World's End      1  300000000
# Spectre                                       2  245000000
# The Dark Knight Rises                         3  250000000
# John Carter                                   4  260000000
# ...                                         ...        ...
# Down Terrace                               4772      31192
# Clerks                                     4773      27000
# Dry Spell                                  4781      22000
# Tin Can Man                                4791         13
# Primer                                     4796       7000
#
#                                                                             genres  \
# title
# Avatar                                    Action Adventure Fantasy Science Fiction
# ...

# %%
movies_df.dropna(axis=1)
# Out:
#                                           index     budget      id  \
# title
# Avatar                                        0  237000000   19995
# Pirates of the Caribbean: At World's End      1  300000000     285
# Spectre                                       2  245000000  206647
# The Dark Knight Rises                         3  250000000   49026
# John Carter                                   4  260000000   49529
# ...                                         ...        ...     ...
# El Mariachi                                4798     220000    9367
# Newlyweds                                  4799       9000   72766
# Signed, Sealed, Delivered                  4800          0  231617
# Shanghai Calling                           4801          0  126186
# My Date with Drew                          4802          0   25975
#
#                                          original_language  \
# title
# Avatar                                                  en
# ...

# %%
movies_df.fillna(0)
# Out:
#                                           index     budget  \
# title
# Avatar                                        0  237000000
# Pirates of the Caribbean: At World's End      1  300000000
# Spectre                                       2  245000000
# The Dark Knight Rises                         3  250000000
# John Carter                                   4  260000000
# ...                                         ...        ...
# El Mariachi                                4798     220000
# Newlyweds                                  4799       9000
# Signed, Sealed, Delivered                  4800          0
# Shanghai Calling                           4801          0
# My Date with Drew                          4802          0
#
#                                                                             genres  \
# title
# Avatar                                    Action Adventure Fantasy Science Fiction
# ...

# %%
df =pd.DataFrame({ 'Age' : [25, 30, np.nan, 40. 35],
                  'Department' : ['HR', 'Finance', 'Finance', np.nan, 'iT']})

print(df)
df['Age'].fillna(df["Age"])

# %%
df_ffill

# %%
import pandas as pd

# Sample dataset with inconsistent date formats
df = pd.DataFrame({
    'Date': ['2025-01-05', '05/01/2025', 'Jan 5, 2025', '2025.01.05']
})

# Convert all dates to standard ISO format (YYYY-MM-DD)
df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

print(df)
# Out:
#          Date
# 0  2025-01-05
# 1         NaN
# 2         NaN
# 3         NaN

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'BOB', 'charlie', 'DAVID']
})

# Convert all names to lowercase
df['Name_lower'] = df['Name'].str.lower()
print(df)

# Convert all names to uppercase
df['Name_upper'] = df['Name'].str.upper()

print(df)
# Out:
#       Name Name_lower
# 0    Alice      alice
# 1      BOB        bob
# 2  charlie    charlie
# 3    DAVID      david
#       Name Name_lower Name_upper
# 0    Alice      alice      ALICE
# 1      BOB        bob        BOB
# 2  charlie    charlie    CHARLIE
# 3    DAVID      david      DAVID

# %%
import pandas as pd

movies_df = pd.read_csv("movies.csv.zip")

# Convert movie titles to lowercase
movies_df['title_lower'] = movies_df['title'].str.lower()

print(movies_df)

# Convert movie titles to uppercase
movies_df['title_upper'] = movies_df['title'].str.upper()

print(movies_df)
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
import pasndas as
from scipy.stats.import.spearmanr

# %%
def hamming_distance(str1, str2):
  if len(srt1) != len(str2):
    raise ValueError('Strings must be equal length')

    return sum(ch1 != ch2 for ch1, ch2 in zip(str1, str2))

    s1 = 'Deekshitha
    s2 = 'Deekshitha'

    dist = hamming_distance(s1, s2)
    print(f"Hamming Distance between '{s1}' and '{s2}' : {dist}" )
# Out:
#   File "/tmp/ipykernel_9883/1039993372.py", line 7
#     s1 = 'Deekshitha
#          ^
# SyntaxError: unterminated string literal (detected at line 7)

# %%
def jaccard_index(str1, str2):
  set1, set2 = set(str1.split()), set(str2.split())
  intersection = set1.intersection(set2)
  union = set1.union(set2)
  return len(intersection) / len(union)

  s1 = "data science is fun"
  s2 = "science makes data useful"

  print("jaccard Index:", jaccard_index(s1, s2))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
s1 = "data science is fun"
s2 = " science makes data useful"

vectorizer = CountVectorizer().fit([s1, s2])
vectors = vectorizer.transform([s1, s2])

cos_sim = cosine_similarity(vectors[0], vectors[1])[0][0]
print("Cosine Similarity:", cos_sim)
# Out:
# Cosine Similarity: 0.5

# %%
def lcs_length(X, Y):
  m, n= len(X), len(Y)
  dp = [[0] * (n + 1) for _ in range(m + 1)]

  for i in range(m):
     for j in range(n):
        if X[i] == Y[j]:
            dp[i+1][j+1]

# %%
import matplotlib.pyplot as plt

y1 = []
y2 = []
x = range(-100, 100, 10)
for i in x:
   y1.append(i**2)
for i in x:
  y2.append(-i**2)
plt.plot(x,y1)
plt.plot(x,y2)

plt.xlabel('x')
plt.ylabel('y')
plt.title('simple graph')
plt.axhline()     #horizontal line
plt.axvline()      # vertical line
plt.show()

# %%
import matplotlib.pyplot as plt

y1 = []
y2 = []
x = range(-100, 100, 10)
for i in x:
   y1.append(i**2)
for i in x:
  y2.append(-i**2)
plt.plot(x,y1)
plt.plot(x,y2)

plt.xlabel('x')
plt.ylabel('y')
plt.title('simple graph')
plt.axhline(color='red')
plt.axvline(color='green')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('temporal.csv')
plt.plot(df['deep learning'], df['machine learning'], color='red')
plt.xlabel('deep learning')
plt.ylabel('machince learning')
plt.title('line plot')
plt.show()
df
# Out:
#             Mes  data science  machine learning  deep learning  categorical
# 0    2004-01-01            12                18              4            1
# 1    2004-02-01            12                21              2            1
# 2    2004-03-01             9                21              2            1
# 3    2004-04-01            10                16              4            1
# 4    2004-05-01             7                14              3            1
# ..          ...           ...               ...            ...          ...
# 189  2019-10-01            90                98             98            0
# 190  2019-11-01            87                97             96            0
# 191  2019-12-01            81                89             91            0
# 192  2020-01-01            94                94             93            1
# 193  2020-02-01           100                99             99            1
#
# [194 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('temporal.csv')
plt.plot(df['deep learning'],color='orange')
plt.plot(df['machine learning'],color='green')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('simple graph')
plt.grid(True)
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs) -> 'Legend'>

# %%
import matplotlib.pyplot as plt
x_values = [0,1,2,3,4,5]
y_values = [0,1,4,9,16,25]
plt.title('scatter graph')
plt.scatter(x_values, y_values, color="blue", s=30)
plt.show()

# %%
import matplotlib.pyplot as plt
x_values = [0,1,2,3,4,5]
y_values = [0,1,4,9,16,25]
plt.scatter(x_values,y_values, s=30, color='green', marker="^")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('My scatter plot!')
plt.legend()
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_6739/1815292471.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt
x_values = [0,1,2,3,4,5]
y_values = [0,1,4,9,16,25]
plt.scatter(df['deep learning'], df['data science'], s=30, color='red', marker="^")
plt.xlabel('deep learning')
plt.ylabel('data science')
plt.title('Scatter')
plt.legend()
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_6739/1118075080.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt
values = [5, 6, 3, 7, 2]
names = ['A', 'B', 'C', 'D', 'E']
plt.bar(names, values, color='aquamarine')
plt.show()

# %%
import matplotlib.pyplot as plt
values = [5, 6, 3, 7, 2]
names = ['A', 'B', 'C', 'D', 'E']    # used for compiling 2 variables
plt.barh(names, values, color='green')
plt.show()

# %%
import matplotlib.pyplot as plt
values = [5, 6, 3, 7, 2]
names = ['A', 'B', 'C', 'D', 'E']
c1=['aqua','aquamarine']
c2=['b','g']
plt.bar(names, values, width=0.8, color=c1)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('My bar chart!')
plt.show()

# %%
import seaborn as sns
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Corrected: Removed invalid 'import color palette:'
# Corrected: Load 'tips' dataset using seaborn.load_dataset()
df=sns.load_dataset("tips")

sns.countplot(x='sex',data=df,palette='Set1')
plt.show()
# Out:
# /tmp/ipykernel_1691/1956842655.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=df,palette='Set1')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("Iris(1).csv")
sns.countplot(x="Species",data=df,color='blue')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("Iris(1).csv")
sns.lineplot(x="SepalLengthCm",y="SepalWidthCm",data=data,color='aquamarine')
sns.set_style("darkgrid")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("Iris(1).csv")
sns.lineplot(x="SepalLengthCm",y="SepalWidthCm",data=data,color='aquamarine')
sns.set_style("darkgrid")
plt.show()

# %%
import seaborn
import matplotlib.pyplot as plt
data=seaborn.load_dataset('tips')
c_p={'Male':'aquamarine','Female':'aqua'}
seaborn.pairplot(data,hue='sex',palette=c_p)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x=x,y=y)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x=x,y=y,fill=True)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = np.random.randint(1, 100,(10, 10))
sns.heatmap(data,vmin =30,vmax=70)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = np.random.randint(1, 100,(10, 10))
sns.heatmap(data,cmap='tab20')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = np.random.randint(1, 100,(10, 10))
sns.heatmap(data,cmap='coolwarm',center=50)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

iris = pd.read_csv("Iris(1).csv")

print(iris.head())

sns.heatmap(
    iris.corr(numeric_only=True),
    annot=True,
    cmap="coolwarm"
)

plt.title("Iris Dataset Correlation Heatmap")
plt.show()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("Iris(1).csv")

data = data.select_dtypes(include='number')

sns.heatmap(data, cmap='coolwarm')
plt.show()

# %%
import matplotlib.pyplot as plt
data = [12,15,20,25,25,25,30,32,35,40]
plt.hist(data,bins=5,color='skyblue',edgecolor='black')
plt.hist("Histogram Example")
plt.xlabel("Value Range")
plt.ylabel("Frequency")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

iris = pd.read_csv("Iris(1).csv")

plt.hist(iris["SepalLengthCm"], bins=5, color='pink', edgecolor='black')
plt.title("Histogram of Sepal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

iris = pd.read_csv("Iris(1).csv")

sns.violinplot(x="Species", y="SepalLengthCm", data=iris)

plt.title("Violin Plot of Sepal Length by Species")
plt.xlabel("Species")
plt.ylabel("Sepal Length")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

iris = pd.read_csv("Iris(1).csv")

sns.violinplot(y=iris["SepalLengthCm"])

plt.title("Violin Plot Example")
plt.ylabel("Sepal Length")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

group1 = [12, 15, 20, 25, 30]
group2 = [18, 22, 25, 28, 35]
group3 = [10, 14, 19, 23, 27]

data = [group1, group2, group3]

sns.violinplot(data=data)

plt.title("Three Violin Plots")
plt.xlabel("Groups")
plt.ylabel("Values")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd # Import pandas for read_csv
df = pd.read_csv("Iris(1).csv") # Corrected function to load CSV
sns.violinplot(x='Species',y='PetalLengthCm',data=df) # Corrected column names
plt.title("Violin Plot")
plt.show()

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
print("First 5 rows of dataset:")
print(df.head())
skewness_values=df.skew(numeric_only=True)
print("\nSkewness Values:")
print(skewness_values)
kurtosis_values=df.kurt(numeric_only=True)
print("\nKurtosis Values:")
print(kurtosis_values)
# Out:
# First 5 rows of dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Skewness Values:
# sepal length (cm)    0.314911
# sepal width (cm)     0.318966
# petal length (cm)   -0.274884
# petal width (cm)    -0.102967
# dtype: float64
#
# Kurtosis Values:
# sepal length (cm)   -0.552064
# sepal width (cm)     0.228249
# petal length (cm)   -1.402103
# petal width (cm)    -1.340604
# dtype: float64
